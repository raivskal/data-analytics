# %%
# !pip install langchain

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template("Tell me a story about {first_topic} and {second_topic}")

prompt_template.invoke({"first_topic": "cats", "second_topic" : "dogs"})
# Out:
# StringPromptValue(text='Tell me a story about cats and dogs')
