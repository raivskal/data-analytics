# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# # 08 Bonus - Using VSCode with Databricks

# %% [markdown]
# 1. Open a simple text editor on your computer. Paste the Databricks URL and Personal Access Token (PAT) in the text editor to use for authentication with VSCode.

# %% [markdown]
# 2. Run the following cell to display your Databricks lab URL. Leave this cell open as you will need it to authenticate to Databricks with VSCode.
#
#     Paste the URL into your text editor.

# %%
lab_databricks_url = f'{spark.conf.get("spark.databricks.workspaceUrl")}/'
print(lab_databricks_url)
# Out:
# dbc-7f5587c4-8fc8.cloud.databricks.com/

# %% [markdown]
# 3. Complete the following steps to create a PAT in Databricks for use with VSCode.
#
#    a. First, create a personal access token (PAT) for use with the Databricks CLI in the Databricks Academy Lab.
#
#    b. Click on your username in the top bar, right-click on **User Settings** from the drop-down menu and select *Open in a New Tab*.
#
#    c. In **Settings**, select **Developer**, then to the left of **Access tokens**, select **Manage**.
#
#    d. Click **Generate new token**.
#
#    e. Select **Scope** as **Other APIs**.
#
#    f. Select **API Scope** and check **all APIs (not recommended)**.
#
#    g. Click **Generate**.
#
#    h. Copy the displayed token to the clipboard. You will not be able to view the token again. If you lose the token, you will need to delete it and create a new one.
#
#    i. Paste the PAT in your text editor below the Databricks URL.
#
#    **NOTE:**
#    - Sometimes, Vocareum has issues with the copy button. Highlight your PAT and copy it manually. Confirm it was copied successfully.
#    - For training purposes, we are temporarily enabling token access to all APIs. This configuration is not typically recommended for production use.
#    Please ensure you follow your organization's security and governance guidelines when defining token permissions.

# %% [markdown]
# #### **NOTE:** Make sure to open the VSCode lab in a new tab. You will need both the Workspace and VSCode open.
#
# 4. To access VSCode in your lab environment, navigate to the drop-down menu, right-click on **VSCode**, and select *Open in a New Tab*. Leave your text editor open, as you will need the URL and PAT.
#
#    Follow the provided instructions in VSCode.
#
#
#
# ![VSCode Access](./images/vscode_lab.png)

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
