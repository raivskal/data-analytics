# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# # 03 - Deploying a DAB to Multiple Environments
#
# In this demonstration, we will deploy a Databricks project to both a development and production environment using DABs and modify the configuration for each environment.
#
# ### Objectives
# - Explore and modify variables within Declarative Automation Bundles.
# - Leverage the **includes** top-level mapping to define paths that contain configuration files for inclusion in the bundle.
# - Deploy projects across multiple environments using Declarative Automation Bundles.

# %% [markdown]
# ## REQUIRED - SELECT CLASSIC COMPUTE
#
# Before executing cells in this notebook, please select your classic compute cluster in the lab. Be aware that **Serverless** is enabled by default.
#
# Follow these steps to select the classic compute cluster:
#
# 1. Navigate to the top-right of this notebook and click the drop-down menu to select your cluster. By default, the notebook will use **Serverless**.
#
# 1. If your cluster is available, select it and continue to the next cell. If the cluster is not shown:
#
#     - In the drop-down, select **More**.
#
#     - In the **Attach to an existing compute resource** pop-up, select the first drop-down. You will see a unique cluster name in that drop-down. Please select that cluster.
#
# **NOTE:** If your cluster has terminated, you might need to restart it in order to select it. To do this:
#
# 1. Right-click on **Compute** in the left navigation pane and select *Open in new tab*.
#
# 1. Find the triangle icon to the right of your compute cluster name and click it.
#
# 1. Wait a few minutes for the cluster to start.
#
# 1. Once the cluster is running, complete the steps above to select your cluster.

# %% [markdown]
# ## A. Classroom Setup
#
# Run the following cell to configure your working environment for this course.
#
# **NOTE:** The `DA` object is only used in Databricks Academy courses and is not available outside of these courses. It will dynamically reference the information needed to run the course.

# %%
# %run ../Includes/Classroom-Setup-03
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Found credentials.cfg in /Workspace/Users/labuser14896263_1777460734@vocareum.com/automated-deployment-with-declarative-automation-bundles-en_us-2.2.0/Automated Deployment with Declarative Automation Bundles/var_labuser14896263_1777460734/credentials.cfg.
# Installed Databricks CLI v0.298.0 at /root/bin/databricks.
# Catalog check for the labs passed.
# Set DA dynamic references to the dev, stage and prod catalogs.
# <table style="width:100%">
#             <tr>
#                 <td style="white-space:nowrap; width:1em">DEV catalog reference: DA.catalog_dev:</td>
#                 <td><input type="text" value="labuser14896263_1777460734_1_dev" style="width: 100%"></td></tr>
#             <tr>
#                 <td style="white-space:nowrap; width:1em">STAGE catalog reference: DA.catalog_stage:</td>
#                 <td><input type="text" value="labuser14896263_1777460734_2_stage" style="width: 100%"></td></tr>
#             <tr>
#                 <td style="white-space:nowrap; width:1em">PROD catalog reference: DA.catalog_prod:</td>
#                 <td><input type="text" value="labuser14896263_1777460734_3_prod" style="width: 100%"></td></tr></table>

# %% [markdown]
# ## IMPORTANT LAB INFORMATION
#
# Recall that your credentials are stored in a file when running [0 - REQUIRED - Course Setup and Authentication]($../0 - REQUIRED - Course Setup and Authentication).
#
# If you end your lab or your lab session times out, your environment will be reset.
#
# If you encounter an error regarding unavailable catalogs or if your Databricks CLI is not authenticated, you will need to rerun the [0 - REQUIRED - Course Setup and Authentication]($../0 - REQUIRED - Course Setup and Authentication) notebook to recreate the catalogs and your Databricks CLI credentials.
#
# **Use classic compute to use the CLI through a notebook.**

# %% [markdown]
# 1. Run the Databricks CLI command below to confirm the Databricks CLI is authenticated.
# </br>
# ##### DATABRICKS CLI ERROR TROUBLESHOOTING:
#   - If you encounter an Databricks CLI authentication error, it means you haven't created the PAT token specified in notebook **0 - REQUIRED - Course Setup and Authentication**. You will need to set up Databricks CLI authentication as shown in that notebook.
#
#   - If you encounter the error below, it means your `databricks.yml` file is invalid due to a modification. Even for non-DAB CLI commands, the `databricks.yml` file is still required, as it may contain important authentication details, such as the host and profile, which are utilized by the CLI commands.
#
# ![CLI Invalid YAML](../Includes/images/databricks_cli_error_invalid_yaml.png)

# %%
# %sh
databricks catalogs list
# Out:
# Name                    Type                  Comment
# dbacademy_cdc_diabetes  DELTASHARING_CATALOG  # CDC Diabetes Health Indicators
#
# ## Attribution
#
# This course uses the CDC Diabetes Health Indicators Dataset, which is licensed under CC0: Public Domain.
#
# ## License Information
#
# You can find more details about the "CDC Diabetes Health Indicators Dataset" on [Kaggle](https://www.kaggle.com/datasets/alexteboul/diabetes-health-indicators-dataset) and[UC Irvine ML Repository](https://archive.ics.uci.edu/dataset/891/cdc+diabetes+health+indicators)
#
# The "CDC Diabetes Health Indicators Dataset" is distributed under the CC0: Public Domain license. Please review the license terms before using the dataset.
#
# For any questions or inquiries regarding the dataset or its usage, please refer to the above pages for contact information.
#
# ---
# Note: This README is provided as part of the dataset attribution for educational purposes. Please ensure compliance with the dataset's licensing terms and conditions.
#
# labuser14896263_1777460734_1_dev    MANAGED_CATALOG
# labuser14896263_1777460734_2_stage  MANAGED_CATALOG
# labuser14896263_1777460734_3_prod   MANAGED_CATALOG
# dbacademy                           MANAGED_CATALOG
# labuser14896263_1777460734          MANAGED_CATALOG
# main                                MANAGED_CATALOG  Main catalog (auto-created)
# samples                             SYSTEM_CATALOG   These sample datasets are made available by third party data providers as well as open data sources. You can learn more about each data set by clicking on each one.
#
# To discover more instantly available, free data sets across a wide range of industry use cases, visit [Databricks Marketplace](/marketplace).
#
# Please note that the third party data sets represent a reduced portion of the available data attributes, volume, and data types available from providers, and are intended for educational rather than production purposes.
# system  SYSTEM_CATALOG  System catalog (auto-created)

# %% [markdown]
# 2. Run the `databricks -v` command to view the version of the Databricks CLI. Confirm that the cell returns version **v0.298.0**.

# %%
# %sh
databricks -v
# Out:
# Databricks CLI v0.298.0

# %% [markdown]
# ## B. Explore the Development and Production Data

# %% [markdown]
# 1. Preview the development data in your **username_1_dev** catalog. Note the following:
#    - It contains 7,500 rows (excluding the header column).
#    - The PII data is masked.
#
# **NOTE:** In this scenario, the sample data in the development environment is a subset of production data used for testing. We will testing later.

# %%
spark.sql(f'''
SELECT *
FROM text.`/Volumes/{DA.catalog_dev}/default/health`
''').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>ID,PII,date,HighCholest,HighBP,BMI,Age,Education,income,Diabetes_binary</td></tr><tr><td>0,********,2025-01-01,0,1.0,26.0,4.0,6.0,94607,0.0</td></tr><tr><td>1,********,2025-01-01,1,1.0,26.0,12.0,6.0,78231,0.0</td></tr><tr><td>2,********,2025-01-01,0,0.0,26.0,null,6.0,99310,0.0</td></tr><tr><td>3,********,2025-01-01,2,1.0,28.0,null,6.0,99665,0.0</td></tr><tr><td>4,********,2025-01-01,0,0.0,29.0,8.0,5.0,81819,0.0</td></tr><tr><td>5,********,2025-01-01,0,0.0,18.0,null,4.0,65444,0.0</td></tr><tr><td>6,********,2025-01-01,1,0.0,26.0,13.0,5.0,49569,0.0</td></tr><tr><td>7,********,2025-01-01,0,0.0,31.0,null,4.0,18870,0.0</td></tr><tr><td>8,********,2025-01-01,0,0.0,32.0,3.0,6.0,78247,0.0</td></tr><tr><td>9,********,2025-01-01,0,0.0,27.0,6.0,4.0,22585,0.0</td></tr><tr><td>10,********,2025-01-01,1,null,24.0,12.0,4.0,40433,0.0</td></tr><tr><td>11,********,2025-01-01,0,0.0,21.0,4.0,6.0,90729,0.0</td></tr><tr><td>12,********,2025-01-01,1,null,27.0,7.0,6.0,97602,0.0</td></tr><tr><td>13,********,2025-01-01,0,null,58.0,10.0,4.0,36199,0.0</td></tr><tr><td>14,********,2025-01-01,1,0.0,29.0,10.0,5.0,8109,0.0</td></tr><tr><td>15,********,2025-01-01,0,0.0,18.0,10.0,4.0,43439,0.0</td></tr><tr><td>16,********,2025-01-01,0,null,30.0,null,5.0,52199,0.0</td></tr><tr><td>17,********,2025-01-01,0,0.0,30.0,10.0,6.0,65523,0.0</td></tr><tr><td>18,********,2025-01-01,0,0.0,20.0,8.0,6.0,99952,0.0</td></tr><tr><td>19,********,2025-01-01,0,1.0,26.0,7.0,5.0,26768,0.0</td></tr><tr><td>20,********,2025-01-01,0,0.0,22.0,6.0,6.0,83465,0.0</td></tr><tr><td>21,********,2025-01-01,0,1.0,29.0,10.0,5.0,83590,0.0</td></tr><tr><td>22,********,2025-01-01,0,null,22.0,8.0,6.0,88452,0.0</td></tr><tr><td>23,********,2025-01-01,0,0.0,30.0,9.0,4.0,44479,0.0</td></tr><tr><td>24,********,2025-01-01,1,0.0,27.0,10.0,4.0,18369,0.0</td></tr><tr><td>25,********,2025-01-01,1,0.0,28.0,8.0,5.0,84008,0.0</td></tr><tr><td>26,********,2025-01-01,0,null,20.0,null,6.0,57336,0.0</td></tr><tr><td>27,********,2025-01-01,1,1.0,32.0,null,4.0,49251,0.0</td></tr><tr><td>28,********,2025-01-01,0,0.0,38.0,null,5.0,54068,0.0</td></tr><tr><td>29,********,2025-01-01,2,0.0,40.0,7.0,5.0,99930,0.0</td></tr><tr><td>30,********,2025-01-01,1,1.0,24.0,4.0,5.0,4267,0.0</td></tr><tr><td>31,********,2025-01-01,0,0.0,24.0,3.0,5.0,18000,0.0</td></tr><tr><td>32,********,2025-01-01,0,0.0,20.0,4.0,4.0,52398,0.0</td></tr><tr><td>33,********,2025-01-01,0,null,20.0,4.0,5.0,14409,0.0</td></tr><tr><td>34,********,2025-01-01,1,1.0,29.0,11.0,5.0,40112,0.0</td></tr><tr><td>35,********,2025-01-01,1,0.0,24.0,null,4.0,35090,0.0</td></tr><tr><td>36,********,2025-01-01,0,0.0,25.0,null,6.0,96176,0.0</td></tr><tr><td>37,********,2025-01-01,0,0.0,136.0,7.0,6.0,38356,0.0</td></tr><tr><td>38,********,2025-01-01,1,0.0,31.0,null,5.0,88051,0.0</td></tr><tr><td>39,********,2025-01-01,1,0.0,27.0,11.0,5.0,88939,0.0</td></tr><tr><td>40,********,2025-01-01,0,0.0,26.0,null,5.0,84332,0.0</td></tr><tr><td>41,********,2025-01-01,1,0.0,27.0,8.0,6.0,90303,0.0</td></tr><tr><td>42,********,2025-01-01,2,1.0,47.0,3.0,6.0,12379,0.0</td></tr><tr><td>43,********,2025-01-01,0,1.0,38.0,4.0,4.0,85904,0.0</td></tr><tr><td>44,********,2025-01-01,2,null,28.0,9.0,6.0,77794,0.0</td></tr><tr><td>45,********,2025-01-01,0,0.0,20.0,3.0,5.0,22761,0.0</td></tr><tr><td>46,********,2025-01-01,0,0.0,19.0,5.0,5.0,89464,0.0</td></tr><tr><td>47,********,2025-01-01,1,0.0,25.0,null,5.0,44977,0.0</td></tr><tr><td>48,********,2025-01-01,0,0.0,26.0,null,5.0,94164,0.0</td></tr><tr><td>49,********,2025-01-01,0,1.0,22.0,13.0,6.0,36012,0.0</td></tr><tr><td>50,********,2025-01-01,0,1.0,31.0,12.0,4.0,73621,0.0</td></tr><tr><td>51,********,2025-01-01,1,null,30.0,null,5.0,39032,0.0</td></tr><tr><td>52,********,2025-01-01,1,1.0,37.0,12.0,5.0,38454,0.0</td></tr><tr><td>53,********,2025-01-01,0,0.0,31.0,5.0,6.0,75862,0.0</td></tr><tr><td>5 ...

# %% [markdown]
# 2. Preview the production data in your **username_3_prod** catalog. Note the following:
#    - It contains 70,695 rows.
#    - The PII data is available. <username>
#
# **NOTE:** In our scenario, a CSV file will be added to the **health** volume in the prod catalog daily. If you inspect the health volume in the production catalog, you will find 3 days already populated.

# %%
spark.sql(f'''
SELECT count(*) AS Total
FROM text.`/Volumes/{DA.catalog_prod}/default/health`
''').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total</th></tr></thead><tbody><tr><td>70695</td></tr></tbody></table></div>

# %%
spark.sql(f'''
SELECT *
FROM text.`/Volumes/{DA.catalog_prod}/default/health`
''').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>ID,PII,date,HighCholest,HighBP,BMI,Age,Education,income,Diabetes_binary</td></tr><tr><td>40351,12a1ffc0-7879-5d08-b397-f57d4ee66626,2025-01-03,1,1.0,27.0,7.0,5.0,89952,1.0</td></tr><tr><td>40352,3cf54a7a-50e2-50aa-bdf8-6bc117686339,2025-01-03,0,0.0,31.0,10.0,4.0,40558,1.0</td></tr><tr><td>40353,348168e9-dbf0-544c-8171-3bbee30447ad,2025-01-03,0,1.0,27.0,10.0,5.0,24270,1.0</td></tr><tr><td>40354,91c4287e-5158-58a4-953f-d1ff9322772d,2025-01-03,2,1.0,26.0,9.0,6.0,81267,1.0</td></tr><tr><td>40355,cb6f3766-d1a5-5d95-967c-0e656a5a7e04,2025-01-03,1,1.0,25.0,10.0,6.0,71423,1.0</td></tr><tr><td>40356,715f414a-3309-561e-b6ed-d634d9ed4f5b,2025-01-03,1,1.0,24.0,4.0,5.0,19977,1.0</td></tr><tr><td>40357,22bbab9d-95fa-57dd-9b87-11041473733e,2025-01-03,1,1.0,30.0,null,6.0,15096,1.0</td></tr><tr><td>40358,f94fbe75-2157-5f6a-84a2-761ce7c16e77,2025-01-03,0,null,24.0,11.0,5.0,31344,1.0</td></tr><tr><td>40359,fed19767-227b-5ee0-88d3-c8be198a989c,2025-01-03,1,1.0,24.0,9.0,5.0,936,1.0</td></tr><tr><td>40360,5eb56cd0-44d7-527f-a800-b1bc801cc326,2025-01-03,2,1.0,42.0,12.0,4.0,12902,1.0</td></tr><tr><td>40361,e6615471-8cd7-5307-a1c3-d7d8229ad99d,2025-01-03,0,1.0,30.0,11.0,6.0,87289,1.0</td></tr><tr><td>40362,483b4719-c62c-5db3-b93e-c702ca162478,2025-01-03,0,1.0,22.0,9.0,4.0,65156,1.0</td></tr><tr><td>40363,7c1ed669-4484-55be-9638-19c52330b494,2025-01-03,1,1.0,20.0,12.0,5.0,6404,1.0</td></tr><tr><td>40364,001c2393-60fe-5ced-859d-588a9ca50094,2025-01-03,0,null,31.0,null,6.0,16853,1.0</td></tr><tr><td>40365,1a61fd31-5812-509e-9f5b-91d3d497e89c,2025-01-03,1,1.0,29.0,7.0,4.0,12229,1.0</td></tr><tr><td>40366,85a23a0e-4295-516d-989c-f1cbbe1948b5,2025-01-03,0,1.0,31.0,10.0,6.0,43770,1.0</td></tr><tr><td>40367,f770c597-c79f-5cd1-aa6b-2c38e5017567,2025-01-03,1,1.0,34.0,5.0,5.0,72117,1.0</td></tr><tr><td>40368,e51245a6-985f-5476-b08b-310eb41b8e55,2025-01-03,1,null,31.0,10.0,5.0,40241,1.0</td></tr><tr><td>40369,44bd91f4-61db-572c-9aff-5ec8473bbbcd,2025-01-03,2,null,28.0,null,5.0,42994,1.0</td></tr><tr><td>40370,624884a0-e248-55a8-bbdf-f6d4607ed718,2025-01-03,1,1.0,37.0,9.0,4.0,12684,1.0</td></tr><tr><td>40371,fef3caa6-1d87-59a3-a91e-4a2b9349fcf1,2025-01-03,2,0.0,23.0,null,6.0,78884,1.0</td></tr><tr><td>40372,1bb3e9b4-de20-54e4-ba5c-08c1a63efeba,2025-01-03,1,1.0,29.0,9.0,5.0,54459,1.0</td></tr><tr><td>40373,a1473a89-3de1-5e46-9b4e-a374bb001155,2025-01-03,0,null,34.0,8.0,5.0,84759,1.0</td></tr><tr><td>40374,ee407480-fdb9-569d-a259-b31373285b36,2025-01-03,2,1.0,29.0,9.0,6.0,11317,1.0</td></tr><tr><td>40375,49f12bb1-70e1-50a6-83f5-43ad5b4cf93d,2025-01-03,1,null,38.0,10.0,4.0,15242,1.0</td></tr><tr><td>40376,964137f1-ae96-5f78-8a4e-1e1dfae1a520,2025-01-03,0,1.0,28.0,10.0,5.0,50821,1.0</td></tr><tr><td>40377,79d25f21-ff3d-503d-ac88-6b2c2dca01d8,2025-01-03,1,0.0,24.0,13.0,6.0,48818,1.0</td></tr><tr><td>40378,f7402d99-ffcb-5d69-9ff2-3739a643ada0,2025-01-03,1,1.0,24.0,13.0,6.0,35244,1.0</td></tr><tr><td>40379,6d07ce45-9f9f-573f-9077-c0e143b8b136,2025-01-03,1,1.0,136.0,11.0,6.0,46581,1.0</td></tr><tr><td>40380,d13bc403-1d4d-5d51-8c20-d2dc95b516eb,2025-01-03,0,null,21.0,6.0,6.0,96503,1.0</td></tr><tr><td>40381,3661f65f-5672-5131-acb0-822a5abc974b,2025-01-03,1,1.0,27.0,null,6.0,21851,1.0</td></tr><tr><td>40382,31a8bfcc-d735-5b1e-9fa6-f11325fdc763,2025-01-03,0,null,37.0,null,6.0,87579,1.0</td></tr><tr><td>40383,58bd592d-d16b-53ae-ad7d-c6a7c0983242,2025-01-03,0,1.0,35.0,9.0,6.0,9707,1.0</td></tr><tr><td>40384,6f474b2c-f78f-5993-a854-e579d6fb7042,2025-01-03,2,1.0,128.0,11.0,5.0,35046,1.0</td></tr><tr><td>40385,c8150a4e-f570-5da4-9fd6-f41619d76e90,2025-01-03,1,1.0,21.0,13.0,6.0,35719,1.0</td></tr><tr><td>40386,77ae2022-0fc2-5121-bed1-35cda989d55e,2025-01-03,1,null,23.0,9.0,6.0,67316,1.0</td></tr><tr><td>40387,4e9e0b22-2137-54f1-b969-0d33578ff7c6,2025-01-03,1,1.0,133.0,null,6.0,99621,1.0</td></tr><tr><td>40388,311bd699-aed0-59e ...

# %% [markdown]
# ## C. Deploy a DAB to Multiple Environments (Development and Production)
#
# In this example, we will be using the same job from demonstration 01. Here are the desired configurations of each environment (catalog):
#
# #### Development target configuration requirements:
# - Use the value **username_1_dev** for the development catalog to read and write to.
# - Run the job using the **small lab cluster** since the development data is small and static.
# - Make the development environment the **default** environment.
#
# #### Production target configuration requirements:
# - Use the value **username_3_prod** for the production catalog to access the production data.
# - Run the job using serverless compute since the data will continually grow, letting Databricks Serverless adjust to the compute needs.

# %% [markdown]
# 1. Open the **./resources/demo_03_job.job.yml** file in a new tab and explore the job configuration.
#
#    a. The job key name is **demo03_job**.
#
#    b. The job name is **${bundle.target}\_demo3_dab_${workspace.current_user.userName}**.
#
#    c. The job is using the **../src/create_bronze_table.py** and **../src/create_silver_table.py** notebooks.
#
#    d. In the YAML file, scroll down and notice that the parameters for this job are using variables:
#    ```YAML
#       parameters:
#       - name: display_target
#         default: ${bundle.target}
#       - name: catalog_name
#         default: ${var.target_catalog}
#     ```
#
#    e. No cluster is being specified, so this job by default will run on Serverless compute.
#
#    f. Leave this tab open.

# %% [markdown]
# 2. Run the follow code to obtain your lab user name. You will need this for the next section.

# %%
print(DA.catalog_name)
# Out:
# labuser14896263_1777460734

# %% [markdown]
# 3. In your other tab, navigate to the **./databricks.yml** file located in the main demonstration folder and explore the bundle. Notice the following:
#
#    a. This bundle is named **demo03_bundle**.
#
#    b. This bundle contains an **include** top-level mapping, which specifies the path to the **./resources/demo_03_job.job.yml** file. This YAML file will define the job for the **resources** mapping as you saw in the previous step.
#
#    **NOTE:** As your project grows, it's best practice to modularize the resources of the DAB.
#
#    c. This DAB also contains a **variable** top-level mapping. Let's modify and view the defined variables:
#
#       - The `my_lab_user_name` variable uses the substitute variable `${workspace.current_user.short_name}`. This will obtain your username for the lab and will be used to propagate the correct value to the remaining variables dynamically for each catalog.
#
#       - The `catalog_dev` variable uses the `my_lab_user_name` variable and appends **_1_dev** to your user name to reference your development catalog.
#
#       - The `catalog_prod` variable uses the `my_lab_user_name` variable and appends **_3_prod** to your user name to reference your production catalog.
#
#       - The `target_catalog` variable by default references your default catalog. Remember, this variable is being used in your job parameter specified in your **./resources/demo_03_job.job.yml** configuration:
#
#       </br>
#
#     ```YAML
#       parameters:
#       - name: display_target
#         default: ${bundle.target}
#       - name: catalog_name
#         default: ${var.target_catalog}
#     ```
#    </br>
#
#       - The `raw_data_path` variable references the **health** volume using the `target_catalog` value, which by default references the **health** volume in your default catalog.
#
#       - **TO DO:** The `cluster_id` variable will use a lookup variable to obtain the cluster ID for the specific lab user. By default, in the Databricks Academy lab, your cluster name is your user name. So, here get your username from the cell above and paste the cluster name next to cluster. This will look up the cluster id from the cluster name.
#
#    d. Leave this tab open.

# %% [markdown]
# 4. In the **databricks.yml** file, explore the **targets** first-level mapping. Notice the following:
#
#    a. When deploying to the **development** target:
#
#       - It is set to **development** mode.
#
#       - It is the **default** target.
#
#       - The root path where the files are placed will end with the target name, **development**.
#
#       - In development, we are modifying the compute for each task in the **resources** mapping. Here, we are adding our small lab compute to process the tasks using the lookup variable `my_cluster_id` we defined earlier. We are doing this because, in development, we know our data is small and don't need large compute resources.
#
#    b. When deploying to the **production** target:
#
#       - It is set to **production** mode.
#
#       - The `target_catalog` variable is modified from the default value of `${var.catalog_dev}` to `${var.catalog_prod}`. This will read from our production catalog and write to the production catalog when deployed in production.
#
#       - The root path where the files are placed will end with the target name, **production**.
#
#       - The job will run in the **Serverless** mode since are not overriding the compute of the specified job in production.
#
# **NOTES:**
# - If available, we could specify the **host** and modify which Databricks Workspace to run this in. In our lab, we only have one Workspace, so we are isolating environments by catalogs.
#
# - In this example, we kept it simple and modified a few configurations for the **production** target. [You can modify a variety of other configurations](https://docs.databricks.com/aws/en/dev-tools/bundles/settings).

# %% [markdown]
# 5. Let's validate the bundle for this demonstration. Confirm that the bundle validated correctly.
#
#     **NOTE:** If the bundle does not validate, read the error and fix the issue. Common issues include:
#
#     - Missing file extensions on the notebook paths within the **demo_03_job.job.yml** file.
#
#     - Failing to modify the variables correctly in the **databricks.yml** file.

# %%
# %sh
databricks bundle validate
# Out:
# Name: demo03_bundle
# Target: development
# Workspace:
#   User: labuser14896263_1777460734@vocareum.com
#   Path: /Workspace/Users/labuser14896263_1777460734@vocareum.com/.bundle/demo03_bundle/development
#
# Validation OK!

# %% [markdown]
# 6. You can run the `databricks bundle validate --output json` to view details of the bundle configuration in JSON format. This helps you identify all of the configurations within your DAB. You can use these values as variable substitutions.
#
#
# Here are some commonly used substitutions:
#
# - ${bundle.name}
#
# - ${bundle.target}  # Use this substitution instead of ${bundle.environment}
#
# - ${workspace.host}
#
# - ${workspace.current_user.short_name}
#
# - ${workspace.current_user.userName}
#
# - ${workspace.file_path}
#
# - ${workspace.root_path}
#
# - ${resources.jobs.<job-name>.id}
#
# - ${resources.models.<model-name>.name}
#
# - ${resources.pipelines.<pipeline-name>.name}
#
#
# For example, in the JSON configuration below, notice that
# - `bundle.target` is *development* in the JSON. Recall we use the `${bundle.target}` variable within our YAML file.
# - in the JSON output look for "workspace", then "current_user", then "short_name". Notice this value will return your user name without the vocareum extension.

# %%
# %sh
databricks bundle validate --output json
# Out:
# {
#   "bundle": {
#     "deployment": {
#       "lock": {
#         "enabled": false
#       }
#     },
#     "environment": "development",
#     "git": {
#       "bundle_root_path": "."
#     },
#     "mode": "development",
#     "name": "demo03_bundle",
#     "target": "development"
#   },
#   "include": [
#     "resources/demo_03_job.job.yml"
#   ],
#   "presets": {
#     "jobs_max_concurrent_runs": 4,
#     "name_prefix": "[dev labuser14896263_1777460734] ",
#     "pipelines_development": true,
#     "source_linked_deployment": true,
#     "tags": {
#       "dev": "labuser14896263_1777460734"
#     },
#     "trigger_pause_status": "PAUSED"
#   },
#   "resources": {
#     "jobs": {
#       "demo03_job": {
#         "deployment": {
#           "kind": "BUNDLE",
#           "metadata_file_path": "/Workspace/Users/labuser14896263_1777460734@vocareum.com/.bundle/demo03_bundle/development/state/metadata.json"
#         },
#         "edit_mode": "UI_LOCKED",
#         "format": "MULTI_TASK",
#         "max_concurrent_runs": 4,
#         "name": "[dev labuser14896263_1777460734] development_demo3_dab_labuser14896263_1777460734@vocareum.com",
#         "parameters": [
#           {
#             "default": "development",
#             "name": "display_target"
#           },
#           {
#             "default": "labuser14896263_1777460734_1_dev",
#             "name": "catalog_name"
#           }
#         ],
#         "queue": {
#           "enabled": true
#         },
#         "tags": {
#           "dev": "labuser14896263_1777460734"
#         },
#         "tasks": [
#           {
#             "existing_cluster_id": "0429-110619-vlx6pmhe",
#             "notebook_task": {
#               "notebook_path": "/Workspace/Users/labuser14896263_1777460734@vocareum.com/automated-deployment-with-declarative-automation-bundles-en_us-2.2.0/Automated Deployment with Declarative Automation Bundles/03 - Deploying a DAB to Multiple Environments/src/create_bronze_table",
#               "source": "WORKSPACE"
#             },
#             "task_key": "create_bronze_table"
#           },
#           {
#             "depends_on": [
#               {
#                 "task_key": "create_bronze_table"
#               }
#             ],
#             "existing_cluster_id": "0429-110619-vlx6pmhe",
#             "notebook_task": {
#               "notebook_path": "/Workspace/Users/labuser14896263_1777460734@vocareum.com/automated-deployment-with-declarative-automation-bundles-en_us-2.2.0/Automated Deployment with Declarative Automation Bundles/03 - Deploying a DAB to Multiple Environments/src/create_silver_table",
#               "source": "WORKSPACE"
#             },
#             "task_key": "create_silver_table"
#           }
#         ]
#       }
#     }
#   },
#   "sync": {
#     "paths": [
#       "."
#     ]
#   },
#   "variables": {
#     "catalog_dev": {
#       "default": "labuser14896263_1777460734_1_dev",
#       "description": "Development catalog for the project. Append _1_dev to the user name.",
#       "value": "labuser14896263_1777460734_1_dev"
#     },
#     "catalog_prod": {
#       "default": "labuser14896263_1777460734_3_prod",
#       "description": "Production catalog for the project. Append _3_prod to the user name.",
#       "value": "labuser14896263_1777460734_3_prod"
#     },
#     "my_cluster_id": {
#       "description": "Get the lab cluster ID using a lookup variable.",
#       "lookup": {
#         "cluster": "labuser14896263_1777460734"
#       },
#       "value": "0429-110619-vlx6pmhe"
#     },
#     "my_lab_user_name": {
#       "default": "labuser14896263_1777460734",
#       "description": "Add your lab user name",
#       "value": "labuser14896263_1777460734"
#     },
#     "raw_data_path": {
#       "default": "/Volumes/labuser14896263_1777460734_1_dev/default/health",
#       "description": "Path to source CSV files to ingest (dev/stage/prod) - default is 'dev'.",
#       "value": "/Volumes/labuser14896263_1777460734_1_dev/default/health"
#     },
#     "target_catalog": {
#       "default": "labuser14896263_1777460734_1_dev",
#       "description": "Target catalog to use for deployment - default is 'dev'.",
#       "value": "labuser14896263_1777460734_1_dev"
#     }
#   },
#   "workspace": {
#     "artifact_path": "/Workspace/Users/labuser14896263_1777460734@vocareum.com/.bundle/demo03_bundle/development/artifacts",
#     "current_user": {
#       "active": true,
#       "displayName": "labuser14896263_1777460734@vocareum.com",
#       "domain_friendly_name": "labuser14896263-1777460734",
#       "emails": [
#         {
#           "primary": true,
#           "type": "work",
#           "value": "labuser14896263_1777460734@vocareum.com"
#         }
#       ],
#       "groups": [
#         {
#           "$ref": "Groups/2122728381166150",
#           "display": "Group-lab-14896263-5140850-1777460733",
#           "type": "direct",
#           "value": "2122728381166150"
#         },
#         {
#           "$ref": "Groups/87153253186261",
#           "display": "users",
#           "type": "direct",
#           "value": "87153253186261"
#         }
#       ],
#       "id": "78859958644318",
#       "name": {
#         "givenName": "labuser14896263_1777460734@vocareum.com"
#       },
#       "schemas": [
#         "urn:ietf:params:scim:schemas:core:2.0:User",
#         "urn:ietf:params:scim:schemas:extension:workspace:2.0:User"
#       ],
#       "short_name": "labuser14896263_1777460734",
#       "userName": "labuser14896263_1777460734@vocareum.com"
#     },
#     "file_path": "/Workspace/Users/labuser14896263_1777460734@vocareum.com/.bundle/demo03_bundle/development/files",
#     "resource_path": "/Workspace/Users/labuser14896263_1777460734@vocareum.com/.bundle/demo03_bundle/development/resources",
#     "root_path": "/Workspace/Users/labuser14896263_1777460734@vocareum.com/.bundle/demo03_bundle/development",
#     "state_path": "/Workspace/Users/labuser14896263_1777460734@vocareum.com/.bundle/demo03_bundle/development/state"
#   }
# }

# %% [markdown]
# ### C1. Deploy to the Development Environment

# %% [markdown]
# 1. Let's delete the tables **health_bronze_demo03** and **health_silver_demo03** if they exist in our development catalog to verify that our bundle is creating the tables correctly. Run the code and confirm that the tables are not in your **_1_dev** catalog. The output from the following cell will display any other table that exists inside the **default** schema except for `health_bronze_demo03` and `health_silver_demo03`.

# %%
del_table(DA.catalog_dev, 'default', 'health_bronze_demo03')
del_table(DA.catalog_dev, 'default', 'health_silver_demo03')

spark.sql(f'''SHOW TABLES IN {DA.catalog_dev}.default''').display()
# Out:
# Deleting the table labuser14896263_1777460734_1_dev.default.health_bronze_demo03 if it exists.
# Deleting the table labuser14896263_1777460734_1_dev.default.health_silver_demo03 if it exists.
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# 2. Let's deploy the bundle to the **development** environment using the specific configurations.
#
# **NOTE:** If you do not specify `-t development`, it will deploy to this environment by default since the configuration `default: True` is used for the development target in the **databricks.yml** file. However, it's better to be explicit.

# %%
# %sh
databricks bundle deploy -t development
# Out:
# Source-linked deployment is enabled. Deployed resources reference the source files in your working tree instead of separate copies.
# Deploying resources...
# Updating deployment state...
# Deployment complete!

# %% [markdown]
# 3. When the cell above completes (in about a minute), view the deployed job named `[dev username] development_demo3_dab_<username>`
#
# In the job, check the following:
#
# - Select the job tasks and confirm that each task is using our lab compute cluster specified in the configuration.
#
# - Find the **Job parameters** section in the right details pane. Note the following values:
#
#     **Job parameters**
#     - **catalog_name** - `<username>_1_dev`
#     - **display_target** - `development`
#
# Recall that we deployed the job in development mode, and it’s using the default variables we created in the **databricks.yml** file to read from and write to our development catalog.
#
# Note: When running a job from the command line, you will need to pass the job key from the job YAML file. For example, in our scenario, we have the following in our job YAML file:
#
#
# ```YAML
#   resources:
#     jobs:
#       demo03_job:
#         name: ${bundle.target}_demo3_dab_${workspace.current_user.userName}
#         ...
# ```
#
# So, we will run `databricks bundle run -t development demo03_job` and _not_ `databricks bundle run -t development development_demo3_dab_<username>` or any variant.

# %% [markdown]
# 4. Run the job in the development environment.
#
#     **NOTE:** While the job is running, let's take a moment to address any specific questions.

# %%
# %sh
databricks bundle run -t development demo03_job
# Out:
# Run URL: https://dbc-7f5587c4-8fc8.cloud.databricks.com/?o=7474652962058183#job/331799514102916/run/652433209496828
#
# 2026-04-29 12:14:25 "[dev labuser14896263_1777460734] development_demo3_dab_labuser14896263_1777460734@vocareum.com" RUNNING
# 2026-04-29 12:15:05 "[dev labuser14896263_1777460734] development_demo3_dab_labuser14896263_1777460734@vocareum.com" TERMINATED SUCCESS
# Output:
# =======
# Task create_bronze_table:
#
# =======
# Task create_silver_table:

# %% [markdown]
# 5. Run the following cell to view the available tables in the development catalog after the job completes (in about 2 minutes).
#
#     Notice that the two new tables, **health_bronze_demo03** and **health_silver_demo03**, were created.

# %%
spark.sql(f'SHOW TABLES IN {DA.catalog_dev}.default').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>health_bronze_demo03</td><td>false</td></tr><tr><td>default</td><td>health_silver_demo03</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# 6. Count the number of rows in the **health_bronze_demo03** table in the **user_name_1_dev** catalog. Notice that it contains 7,500 rows, as we are using the development data.
#
#     This confirms that our job correctly read from and wrote to the development catalog.

# %%
spark.sql(f'''
    SELECT count(*) 
    FROM {DA.catalog_dev}.default.health_bronze_demo03''').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>7500</td></tr></tbody></table></div>

# %% [markdown]
# ### C2. Deploy to the Production Environment
# Now that we've confirmed the job ran in the development environment let's easily deploy the job to run in our production environment!
#
# **NOTE:** Typically when running in production you will want to run the job using a service principal. For more information, check out the [Set a bundle run identity](https://docs.databricks.com/aws/en/dev-tools/bundles/run-as).
#
# For demonstration purposes, we are simply running the production job as the user.

# %% [markdown]
# 1. Before we deploy to production let's check (and delete if necessary) the tables in the `<username>_3_prod` catalog. Notice that the tables `health_bronze_demo03` and `health_silver_demo03` are not present in the production catalog.

# %%
del_table(DA.catalog_prod, 'default', 'health_bronze_demo03')
del_table(DA.catalog_prod, 'default', 'health_silver_demo03')

spark.sql(f'SHOW TABLES IN {DA.catalog_prod}.default').display()
# Out:
# Deleting the table labuser14896263_1777460734_3_prod.default.health_bronze_demo03 if it exists.
# Deleting the table labuser14896263_1777460734_3_prod.default.health_silver_demo03 if it exists.
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# 2. Let's view the **production** configurations. Note the following:
#
# ```YAML
#   production:
#     mode: production
#     workspace:
#       # host: https://dbc-d9be2316-40bd.cloud.databricks.com/
#       root_path: /Workspace/Users/${workspace.current_user.userName}/.bundle/${bundle.name}/${bundle.target}
#
#     ## Change variable values when in the production environment to use the production catalog username_3_prod
#     variables:
#         target_catalog: ${var.catalog_prod}
# ```
#
#   - Here, we are modifying the variable `target_catalog` to reference our variable `catalog_prod` that references our production catalog. This overrides the default job parameter in the **./resources/demo_03_job.job.yml** file.
#
#   - We are not adding any overrides regarding the cluster to use for our job. Since we do not provide any overrides, it will use the default set in the **./resources/demo_03_job.job.yml** file, which is using Serverless compute.

# %% [markdown]
# 3. Let's deploy the bundle to the **production** environment using the specified configurations.

# %%
# %sh
databricks bundle deploy -t production
# Out:
# Uploading bundle files to /Workspace/Users/labuser14896263_1777460734@vocareum.com/.bundle/demo03_bundle/production/files...
# Deploying resources...
# Updating deployment state...
# Deployment complete!

# %% [markdown]
# 4. When the cell above completes (in about a minute), view the deployed job named `production_demo3_dab_<username>`.
#
# In the job, check the following:
#
# - Select the job tasks and confirm that each task is using Serverless compute.
#
# - Find the **Job parameters** section in the right details pane. Note the following values:
#
#     **Job parameters**
#     - **catalog_name** - `<username>_3_prod`
#     - **display_target** - `production`
#
# Recall that we deployed the job in production mode, and it’s using the configuration we specified in the **databricks.yml** file to read from and write to our production catalog, and to use Serverless compute.

# %% [markdown]
# 5. Run the production job using the Databricks CLI.

# %%
# %sh
databricks bundle run -t production demo03_job
# Out:
# Run URL: https://dbc-7f5587c4-8fc8.cloud.databricks.com/?o=7474652962058183#job/689317611298587/run/531898463702460
#
# 2026-04-29 12:21:26 "production_demo3_dab_labuser14896263_1777460734@vocareum.com" RUNNING
# 2026-04-29 12:22:26 "production_demo3_dab_labuser14896263_1777460734@vocareum.com" TERMINATED SUCCESS
# Output:
# =======
# Task create_bronze_table:
#
# =======
# Task create_silver_table:

# %% [markdown]
# 6. While the job is running, let's view where the Databricks assets were bundled.
#
#     a. In the main navigation bar, right-click on **Workspace** and select *Open in a New Tab*.
#
#     b. Navigate to **Workspace > Users > your user name**.
#
#     c. Open the **.bundle** folder. Here, you should see the names of the bundles you have deployed (**demo01_bundle** and **demo03_bundle**).
#
#     d. Open the deployed **demo03_bundle** (the bundle name we specified in the **databricks.yml** file for this demonstration).
#
#     e. Here, we can see that we deployed to the **development** and **production** targets.
#
#     f. Select the **production** folder. You will see the **artifacts**, **files**, and **state** folders.
#
#     g. Select the **files** folder.
#
#     h. Notice that all of the files we deployed have been added to this location for the production mode deployment within the Workspace.
#
#     i. Close this tab.

# %% [markdown]
# 7. By now, the **production** job should be completed. Navigate to the job and confirm it executed successfully.

# %% [markdown]
# 8. Run the following code to view the tables in your `<username>_3_prod` catalog. Notice that the production job created the production tables `health_bronze_demo03` and `health_silver_demo03`.

# %%
spark.sql(f'SHOW TABLES IN {DA.catalog_prod}.default').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>health_bronze_demo03</td><td>false</td></tr><tr><td>default</td><td>health_silver_demo03</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# 9. Count the number of rows in the `health_bronze_demo03` table in the `<username>_3_prod` catalog. Notice that it contains over 70,692 rows because it's read from the production data and writing to the production catalog.

# %%
spark.sql(f'''
          SELECT count(*) 
          FROM {DA.catalog_prod}.default.health_bronze_demo03'''
          ).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>70692</td></tr></tbody></table></div>

# %% [markdown]
# ## D. Destroy the Bundles
# Lastly since we are finished with this bundle, let's delete it using the `databricks bundle destroy` command.
#
#
#   By default, you are prompted to confirm permanent deletion of the previously-deployed jobs, pipelines, and artifacts. To skip these prompts and perform automatic permanent deletion, add the `--auto-approve` option to the bundle destroy command.
#
#   **Warning:** Destroying a bundle permanently deletes a bundle’s previously-deployed jobs, pipelines, and artifacts. This action cannot be undone. For more information view [Destroy the bundle](https://docs.databricks.com/en/dev-tools/bundles/work-tasks.html#step-6-destroy-the-bundle)

# %% [markdown]
# 1. Delete the bundles!

# %%
# %sh
databricks bundle destroy --auto-approve
databricks bundle destroy -t production --auto-approve

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
