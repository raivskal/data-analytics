# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# # Streaming Query Lab
# ### Coupon Sales
#
# Process and append streaming data on transactions using coupons.
#
# ##### Objectives
# 1. Read data stream
# 2. Filter for transactions with coupons codes
# 3. Write streaming query results to Delta
# 4. Monitor streaming query
# 5. Stop streaming query
#
# ##### Classes
# - <a href="https://spark.apache.org/docs/latest/api/python/reference/pyspark.ss/api/pyspark.sql.streaming.DataStreamReader.html" target="_blank">DataStreamReader</a>
# - <a href="https://spark.apache.org/docs/latest/api/python/reference/pyspark.ss/api/pyspark.sql.streaming.DataStreamWriter.html" target="_blank">DataStreamWriter</a>
# - <a href="https://spark.apache.org/docs/latest/api/python/reference/pyspark.ss/api/pyspark.sql.streaming.StreamingQuery.html" target="_blank">StreamingQuery</a>

# %% [markdown]
# ## REQUIRED - SELECT CLASSIC COMPUTE
#
# Before executing cells in this notebook, please select your classic compute cluster in the lab. Be aware that **Serverless** is enabled by default.
#
# Follow these steps to select the classic compute cluster:
#
# 1. Navigate to the top-right of this notebook and click the drop-down menu to select your cluster. By default, the notebook will use **Serverless**.
#
# 1. If your cluster is available, select it and continue to the next cell. If the cluster is not shown:
#
#     - In the drop-down, select **More**.
#
#     - In the **Attach to an existing compute resource** pop-up, select the first drop-down. You will see a unique cluster name in that drop-down. Please select that cluster.
#
# **NOTE:** If your cluster has terminated, you might need to restart it in order to select it. To do this:
#
# 1. Right-click on **Compute** in the left navigation pane and select *Open in new tab*.
#
# 1. Find the triangle icon to the right of your compute cluster name and click it.
#
# 1. Wait a few minutes for the cluster to start.
#
# 1. Once the cluster is running, complete the steps above to select your cluster.

# %%
# %run ./Includes/Classroom-Setup-02L
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# ### 1. Read data stream
#
# Assign the resulting DataFrame to **`df`**:
# - Read from Delta files in the source directory specified by **`/Volumes/dbacademy_ecommerce/v01/delta/sales_hist`**
# - Set to process 1 file per trigger

# %%
df = (spark
      .readStream
      .option("maxFilesPerTrigger", 1)
      .format("delta")
      .load('/Volumes/dbacademy_ecommerce/v01/delta/sales_hist')
     )

# %%
# %skip
df = (spark
      .readStream
      .option("maxFilesPerTrigger", 1)
      .format("delta")
      .load('/Volumes/dbacademy_ecommerce/v01/delta/sales_hist')
     )

# %% [markdown]
# **1.1: CHECK YOUR WORK**

# %%
# Define the list of required columns
sales_required_columns = [
    'order_id', 'email', 'transaction_timestamp',
    'total_item_quantity', 'purchase_revenue_in_usd',
    'unique_items', 'items'
]

# %%
DA.validate_dataframe(df,sales_required_columns)
# Out:
# All validations passed!

# %% [markdown]
# ### 2. Filter for transactions with coupon codes
# - Explode the **`items`** field in **`df`** with the results replacing the existing **`items`** field
# - Filter for records where **`items.coupon`** is not null
#
# Assign the resulting DataFrame to **`coupon_sales_df`**.

# %%
from pyspark.sql.functions import col, explode

coupon_sales_df = (df
                   .withColumn("items", explode(col("items")))
                   .filter(col("items.coupon").isNotNull())
                  )

# %%
# %skip
from pyspark.sql.functions import col, explode

coupon_sales_df = (df
                   .withColumn("items", explode(col("items")))
                   .filter(col("items.coupon").isNotNull())
                  )

# %% [markdown]
# **2.1: CHECK YOUR WORK**

# %%
# Expected schema fields and types

expected_fields = {
    "order_id": "LongType",
    "email": "StringType",
    "transaction_timestamp": "LongType",
    "total_item_quantity": "LongType",
    "purchase_revenue_in_usd": "DoubleType",
    "unique_items": "LongType",
    "items": "StructType"
}

# %%
DA.validate_schema(coupon_sales_df.schema,expected_fields)
# Out:
# Schema validation passed!

# %% [markdown]
# ### 3. Write streaming query results to Delta
# - Configure the streaming query to write Delta format files in "append" mode
# - Set the query name to "coupon_sales"
# - Set a trigger interval of 1 second
# - Set the checkpoint location to **`coupons_checkpoint_path`**
# - Set the output path to **`coupons_output_path`**
#
# Start the streaming query and assign the resulting handle to **`coupon_sales_query`**.

# %%
coupons_checkpoint_path = f"{DA.paths.working_dir}/coupon-sales"
coupons_output_path = f"{DA.paths.working_dir}/coupon-sales/output"

coupon_sales_query = (coupon_sales_df
                      .writeStream
                      .outputMode("append")
                      .format("delta")
                      .queryName("coupon_sales")
                      .trigger(processingTime="1 second")
                      .option("checkpointLocation", coupons_checkpoint_path)
                      .start(coupons_output_path))

# %%
# %skip

coupons_checkpoint_path = f"{DA.paths.working_dir}/coupon-sales"
coupons_output_path = f"{DA.paths.working_dir}/coupon-sales/output"

coupon_sales_query = (coupon_sales_df
                      .writeStream
                      .outputMode("append")
                      .format("delta")
                      .queryName("coupon_sales")
                      .trigger(processingTime="1 second")
                      .option("checkpointLocation", coupons_checkpoint_path)
                      .start(coupons_output_path))

# %% [markdown]
# **3.1: CHECK YOUR WORK**
#
# Note: Please wait for stream to get started before validating

# %%
DA.validate_coupon_sales_query(coupon_sales_query,coupons_checkpoint_path,coupons_output_path)
# Out:
# Coupon sales query is active.
# Found at least one file in /Volumes/dbacademy/ops/labuser14574160_1775554594@vocareum_com/coupon-sales.
# Found at least one file in /Volumes/dbacademy/ops/labuser14574160_1775554594@vocareum_com/coupon-sales/output.

# %% [markdown]
# ### 4. Monitor streaming query
# - Get the ID of streaming query and store it in **`queryID`**
# - Get the status of streaming query and store it in **`queryStatus`**

# %%
query_id = coupon_sales_query.id
print(query_id)
# Out:
# aef74b61-969f-4aa4-9a05-fb4f1b5a36ff

# %%
# %skip
query_id = coupon_sales_query.id
print(query_id)

# %%
query_status = coupon_sales_query.status
print(query_status)
# Out:
# {'message': 'Waiting for data to arrive', 'isDataAvailable': False, 'isTriggerActive': False}

# %%
# %skip
query_status = coupon_sales_query.status
print(query_status)

# %% [markdown]
# **4.1: CHECK YOUR WORK**

# %%
DA.validate_query_status(query_status)
# Out:
# Test Passed: Valid query status.

# %% [markdown]
# ### 5. Stop streaming query
# - Stop the streaming query

# %%
coupon_sales_query.stop()

# %%
# %skip
coupon_sales_query.stop()
coupon_sales_query.awaitTermination()

# %% [markdown]
# **5.1: CHECK YOUR WORK**

# %%
DA.validate_query_state(coupon_sales_query)

# %% [markdown]
# ### 6. Verify the records were written in Delta format

# %%
display(spark.read.format("delta").load(coupons_output_path))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>email</th><th>transaction_timestamp</th><th>total_item_quantity</th><th>purchase_revenue_in_usd</th><th>unique_items</th><th>items</th></tr></thead><tbody><tr><td>285712</td><td>wbrown@gonzales-miranda.com</td><td>1592521889512254</td><td>2</td><td>1071.0</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 1071.0, 595.0, 2)</td></tr><tr><td>277921</td><td>campbellkatrina@phillips-duarte.com</td><td>1592458670364116</td><td>1</td><td>850.5</td><td>1</td><td>List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1)</td></tr><tr><td>274566</td><td>gregorytorres@meyer.com</td><td>1592419954844631</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>289539</td><td>levans13@hotmail.com</td><td>1592572270401950</td><td>2</td><td>2016.0</td><td>2</td><td>List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1)</td></tr><tr><td>289539</td><td>levans13@hotmail.com</td><td>1592572270401950</td><td>2</td><td>2016.0</td><td>2</td><td>List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1)</td></tr><tr><td>278572</td><td>jdixon@steele-kennedy.net</td><td>1592474913337711</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>298991</td><td>jamie3419@hotmail.com</td><td>1592636268357203</td><td>1</td><td>940.5</td><td>1</td><td>List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1)</td></tr><tr><td>275792</td><td>meganmiller@gmail.com</td><td>1592427703572736</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>281527</td><td>randolphjimmy@hotmail.com</td><td>1592498653047331</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>288311</td><td>hallryan9@gmail.com</td><td>1592560621183642</td><td>2</td><td>1686.6</td><td>2</td><td>List(NEWBED10, M_PREM_Q, Premium Queen Mattress, 1615.5, 1795.0, 1)</td></tr><tr><td>288311</td><td>hallryan9@gmail.com</td><td>1592560621183642</td><td>2</td><td>1686.6</td><td>2</td><td>List(NEWBED10, P_FOAM_K, King Foam Pillow, 71.10000000000001, 79.0, 1)</td></tr><tr><td>284378</td><td>carterautumn@dudley-sullivan.com</td><td>1592513092147896</td><td>1</td><td>940.5</td><td>1</td><td>List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1)</td></tr><tr><td>277955</td><td>boothjeff@lopez.com</td><td>1592459987942459</td><td>2</td><td>903.6</td><td>2</td><td>List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1)</td></tr><tr><td>277955</td><td>boothjeff@lopez.com</td><td>1592459987942459</td><td>2</td><td>903.6</td><td>2</td><td>List(NEWBED10, P_FOAM_S, Standard Foam Pillow, 53.1, 59.0, 1)</td></tr><tr><td>277614</td><td>johnssamantha@yahoo.com</td><td>1592449450374531</td><td>1</td><td>1795.5</td><td>1</td><td>List(NEWBED10, M_PREM_K, Premium King Mattress, 1795.5, 1995.0, 1)</td></tr><tr><td>274545</td><td>rosemarissa@hotmail.com</td><td>1592419813529279</td><td>1</td><td>1525.5</td><td>1</td><td>List(NEWBED10, M_PREM_F, Premium Full Mattress, 1525.5, 1695.0, 1)</td></tr><tr><td>284337</td><td>avilla@patrick.com</td><td>1592512785786297</td><td>1</td><td>535.5</td><td>1</td><td>List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1)</td></tr><tr><td>297862</td><td>rosschristina@wallace.net</td><td>1592618272162770</td><td>1</td><td>850.5</td><td>1</td><td>List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1)</td></tr><tr><td>277330</td><td>johnny44@simpson-burnett.org</td><td>1592443816024176</td><td>1</td><td>850.5</td><td>1</td><td>List(NEWBED10, M_STAN_F, Standard Full Mattress, 850.5, 945.0, 1)</td></tr><tr><td>270596</td><td>jsimon74@gmail.com</td><td>1592371254810601</td><td>1</td><td>535.5</ ...

# %%
# %skip
display(spark.read.format("delta").load(coupons_output_path))

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
