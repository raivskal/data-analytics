# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
wine_file_name = "/content/drive/MyDrive/Data analytics course/winemag-data-130k-v2.csv"
wine_df = pd.read_csv(wine_file_name, index_col=0)
wine_df.head()
# Out:
#     country  ...               winery
# 0     Italy  ...              Nicosia
# 1  Portugal  ...  Quinta dos Avidagos
# 2        US  ...            Rainstorm
# 3        US  ...           St. Julian
# 4        US  ...         Sweet Cheeks
#
# [5 rows x 13 columns]

# %%
wine_df.price.mean()
# Out:
# 35.363389129985535

# %%
wine_df.points.mean()
# Out:
# 88.44713820775404

# %%
wine_df.variety.describe()
# Out:
# count         129970
# unique           707
# top       Pinot Noir
# freq           13272
# Name: variety, dtype: object

# %%
wine_df.designation.describe()
# Out:
# count       92506
# unique      37979
# top       Reserve
# freq         2009
# Name: designation, dtype: object

# %% [markdown]
# Since we work most of time with the same set of columns - it is easier to observe dataset in focus-oriented way.

# %%
#Let's check columns's indexes
wine_df.iloc[:, 0]
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
#Check how new columns' list will look like
wine_df_order = [0, 3, 4, 11, 2, 5, 12, 6, 7, 8, 9, 10]
wine_df.columns[wine_df_order]
# Out:
# Index(['country', 'points', 'price', 'variety', 'designation', 'province',
#        'winery', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title'],
#       dtype='object')

# %%
#Apply new order of columns and assign to a new Data Frame
wine_df_reordered = wine_df[wine_df.columns[wine_df_order]]
wine_df_reordered.head()
# Out:
#     country  ...                                              title
# 0     Italy  ...                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1  Portugal  ...      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        US  ...      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3        US  ...  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        US  ...  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
# [5 rows x 12 columns]

# %%
wine_df_reordered.country.count()
# Out:
# 129908

# %% [markdown]
# # Data Grouping
#
# Example: how many wines do we have in each country?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
wine_group_country = wine_df_reordered.groupby("country")

# %%
wine_group_country.groups
# Out:
# {'Argentina': [16, 17, 183, 224, 231, 245, 253, 261, 266, 273, 275, 284, 294, 553, 567, 605, 615, 700, 715, 721, 722, 728, 734, 735, 738, 785, 788, 910, 914, 919, 922, 926, 930, 985, 1021, 1040, 1170, 1174, 1178, 1193, 1194, 1195, 1346, 1394, 1482, 1493, 1496, 1497, 1618, 1621, 1622, 1626, 1634, 1646, 1648, 1651, 1665, 1680, 1695, 1790, 1815, 1822, 1844, 1851, 1855, 1899, 1902, 1991, 1992, 1993, 2002, 2012, 2083, 2141, 2155, 2254, 2277, 2291, 2351, 2387, 2551, 2615, 2618, 2673, 2795, 2925, 2934, 2935, 2942, 2947, 2954, 2964, 3045, 3056, 3057, 3120, 3136, 3148, 3149, 3157, ...], 'Armenia': [8170, 66146], 'Australia': [77, 83, 123, 191, 232, 238, 246, 293, 345, 346, 348, 349, 356, 360, 365, 628, 633, 636, 652, 746, 766, 768, 807, 813, 866, 893, 920, 924, 987, 997, 1008, 1074, 1154, 1182, 1198, 1199, 1478, 1636, 1649, 1666, 1706, 1707, 1712, 1723, 1886, 1890, 1891, 1894, 1897, 1903, 1908, 1909, 1930, 1934, 2137, 2256, 2312, 2517, 2587, 2594, 2598, 2600, 2611, 2617, 2631, 2640, 2642, 2949, 2953, 2956, 2958, 2965, 2971, 2981, 2982, 2993, 3080, 3092, 3099, 3135, 3277, 3288, 3363, 3451, 3454, 3459, 3532, 3534, 3547, 3554, 3594, 3595, 3598, 3679, 3880, 3886, 3947, 3949, 3952, 4099, ...], 'Austria': [93, 269, 280, 285, 288, 418, 423, 428, 435, 441, 444, 491, 502, 584, 586, 587, 589, 591, 593, 597, 690, 697, 1043, 1055, 1056, 1101, 1153, 1156, 1158, 1159, 1175, 1320, 1322, 1341, 1422, 1425, 1438, 1441, 1442, 1505, 1681, 1684, 1693, 1912, 1922, 1941, 2048, 2049, 2050, 2051, 2170, 2178, 2265, 2365, 2437, 2528, 2529, 2535, 2547, 2565, 2586, 2588, 2595, 2665, 2685, 2992, 3017, 3025, 3137, 3138, 3139, 3146, 3151, 3187, 3198, 3199, 3202, 3234, 3261, 3531, 3536, 3538, 3550, 3555, 3557, 3646, 3647, 3652, 3656, 3789, 3962, 3983, 4763, 4765, 4777, 4779, 4782, 4783, 4808, 5101, ...], 'Bosnia and Herzegovina': [16467, 96759], 'Brazil': [5852, 9151, 10565, 10579, 12669, 13218, 14726, 14734, 14739, 15989, 20987, 23883, 25068, 25081, 25509, 26923, 26928, 26933, 27108, 27112, 28028, 34202, 36386, 43246, 51451, 51466, 52753, 54026, 55072, 64657, 64677, 72991, 74419, 76129, 79281, 79589, 81076, 87977, 89722, 89726, 89727, 93688, 94573, 97572, 101564, 101565, 101575, 102206, 102209, 104020, 111297, 111301], 'Bulgaria': [6970, 7933, 7938, 8177, 8178, 9140, 9496, 9892, 10026, 11143, 12091, 12433, 13822, 13823, 14374, 14525, 16736, 18220, 18591, 20884, 21815, 23151, 23152, 24103, 25484, 25923, 26819, 28015, 29521, 30045, 30615, 31585, 31606, 32357, 32431, 32443, 32444, 32445, 35926, 36128, 39510, 40411, 41689, 42603, 42622, 43446, 44434, 45955, 45956, 45958, 45967, 45968, 47136, 47138, 47553, 48409, 49072, 49690, 52688, 54078, 57268, 58687, 58703, 58822, 61181, 64372, 64730, 64731, 66843, 66860, 67058, 68333, 68339, 68340, 72556, 72694, 74773, 75084, 75141, 75430, 75805, 76259, 79601, 79818, 79819, 81833, 81883, 81885, 83645, 83739, 84701, 85939, 88129, 95495, 95588, 95829, 96525, 98078, 98084, 98090, ...], 'Canada': [454, 2616, 5129, 5253, 5580, 5657, 6465, 6863, 7125, 7141, 7504, 7513, 7622, 7626, 7779, 7801, 7878, 8147, 8230, 8234, 10003, 10692, 10715, 10727, 10739, 10789, 10790, 10882, 10885, 10890, 10905, 11821, 12140, 12264, 12282, 13062, 13645, 13772, 14613, 15045, 15284, 17086, 17843, 18766, 18863, 19383, 19401, 19870, 20311, 20324, 20628, 20647, 21409, 21413, 21689, 22935, 24527, 26197, 27558, 27612, 27624, 28681, 29388, 29754, 29944, 32268, 32808, 35068, 35181, 35674, 35682, 37980, 38042, 38043, 38210, 39122, 40138, 41204, 41888, 42662, 42664, 43440, 43748, 44318, 45129, 47945, 49037, 49038, 49863, 51445, 51820, 52035, 52663, 52672, 52679, 53299, 53315, 53573, 54122, 54917, ...], 'Chile': [36, 44, 51, 58, 80, 103, 164, 165, 172, 176, 185, 188, 189, 296, 298, 318, 323, 327, 331, 336, 343, 344, 367, 380, 382, 390, 391, 393, 394, 397, 398, 402, 407, 514, 530, 751, 761, 817, 827, 834, 868, 967, 969, 1009, 1057, 1096, 1100, 1129, 1135, 1141, 1150, 1366, 1382, 1473, 1477, 1479, 1480, 1499, 1509, 1519, 1521, 1524, 1546, 1548, 1549, 1769, 1773, 1915, 1916, ...

# %%
wine_group_country.size()
# Out:
# country
# Argentina                  3800
# Armenia                       2
# Australia                  2329
# Austria                    3345
# Bosnia and Herzegovina        2
# Brazil                       52
# Bulgaria                    141
# Canada                      257
# Chile                      4472
# China                         1
# Croatia                      73
# Cyprus                       11
# Czech Republic               12
# Egypt                         1
# England                      74
# France                    22093
# Georgia                      86
# Germany                    2165
# Greece                      466
# Hungary                     146
# India                         9
# Israel                      505
# Italy                     19540
# Lebanon                      35
# Luxembourg                    6
# Macedonia                    12
# Mexico                       70
# Moldova                      59
# Morocco                      28
# New Zealand                1419
# Peru                         16
# Portugal                   5691
# Romania                     120
# Serbia                       12
# Slovakia                      1
# Slovenia                     87
# South Africa               1401
# Spain                      6645
# Switzerland                   7
# Turkey                       90
# US                        54504
# Ukraine                      14
# Uruguay                     109
# dtype: int64

# %%
wine_group_country.get_group("Serbia")
# Out:
#        country  ...                                              title
# 5085    Serbia  ...               Milijan Jelić 2011 Morava (Pocerina)
# 22398   Serbia  ...  Agrina 2012 Portuguiser Blauer Portugieser (Fr...
# 29284   Serbia  ...                   Budimir 2009 Sub Rosa Red (Župa)
# 38522   Serbia  ...          Budimir 2009 Margus Margi Riesling (Župa)
# 38927   Serbia  ...               Budimir 2013 Župska Tamjanika (Župa)
# 51794   Serbia  ...              Agrina 2014 Portuguiser (Fruška Gora)
# 64364   Serbia  ...                   Budimir 2009 Sub Rosa Red (Župa)
# 70948   Serbia  ...                   Budimir 2007 Svb Rosa Red (Župa)
# 72861   Serbia  ...          Budimir 2008 Margus Margi Riesling (Župa)
# 108102  Serbia  ...              Agrina 2014 Portuguiser (Fruška Gora)
# 112528  Serbia  ...               Budimir 2013 Župska Tamjanika (Župa)
# 117816  Serbia  ...          Budimir 2008 Margus Margi Riesling (Župa)
#
# [12 rows x 12 columns]

# %%
wine_group_country.sum()
# Out:
#                          points      price
# country
# Argentina                329499    92060.0
# Armenia                     175       29.0
# Australia                206304    81294.0
# Austria                  301389    86105.0
# Bosnia and Herzegovina      173       25.0
# Brazil                     4403     1117.0
# Bulgaria                  12399     2065.0
# Canada                    22968     9071.0
# Chile                    386799    91793.0
# China                        89       18.0
# Croatia                    6367     1807.0
# Cyprus                      959      179.0
# Czech Republic             1047      291.0
# Egypt                        84        0.0
# England                    6777     3566.0
# France                  1962855   731289.0
# Georgia                    7541     1623.0
# Germany                  194529    89586.0
# Greece                    40674    10310.0
# Hungary                   13022     5894.0
# India                       812      120.0
# Israel                    44678    15535.0
# Italy                   1730506   670873.0
# Lebanon                    3069     1074.0
# Luxembourg                  532      140.0
# Macedonia                  1042      187.0
# Mexico                     5968     1875.0
# Moldova                    5145      988.0
# Morocco                    2480      546.0
# New Zealand              125302    37112.0
# Peru                       1337      289.0
# Portugal                 502232   127814.0
# Romania                   10368     1829.0
# Serbia                     1050      294.0
# Slovakia                     87       16.0
# Slovenia                   7662     1985.0
# South Africa             123367    31897.0
# Spain                    580031   185459.0
# Switzerland                 620      597.0
# Turkey                     7928     2217.0
# US                      4827077  1984659.0
# Ukraine                    1177      129.0
# Uruguay                    9456     2878.0

# %%
wine_group_country.mean()
# Out:
#                            points      price
# country
# Argentina               86.710263  24.510117
# Armenia                 87.500000  14.500000
# Australia               88.580507  35.437663
# Austria                 90.101345  30.762772
# Bosnia and Herzegovina  86.500000  12.500000
# Brazil                  84.673077  23.765957
# Bulgaria                87.936170  14.645390
# Canada                  89.369650  35.712598
# Chile                   86.493515  20.786458
# China                   89.000000  18.000000
# Croatia                 87.219178  25.450704
# Cyprus                  87.181818  16.272727
# Czech Republic          87.250000  24.250000
# Egypt                   84.000000        NaN
# England                 91.581081  51.681159
# France                  88.845109  41.139120
# Georgia                 87.686047  19.321429
# Germany                 89.851732  42.257547
# Greece                  87.283262  22.364425
# Hungary                 89.191781  40.648276
# India                   90.222222  13.333333
# Israel                  88.471287  31.768916
# Italy                   88.562231  39.663770
# Lebanon                 87.685714  30.685714
# Luxembourg              88.666667  23.333333
# Macedonia               86.833333  15.583333
# Mexico                  85.257143  26.785714
# Moldova                 87.203390  16.745763
# Morocco                 88.571429  19.500000
# New Zealand             88.303030  26.931785
# Peru                    83.562500  18.062500
# Portugal                88.250220  26.218256
# Romania                 86.400000  15.241667
# Serbia                  87.500000  24.500000
# Slovakia                87.000000  16.000000
# Slovenia                88.068966  24.812500
# South Africa            88.056388  24.668987
# Spain                   87.288337  28.215275
# Switzerland             88.571429  85.285714
# Turkey                  88.088889  24.633333
# US                      88.563720  36.573464
# Ukraine                 84.071429   9.214286
# Uruguay                 86.752294  26.403670

# %%
wine_group_country.mean().sort_values("price")
# Out:
#                            points      price
# country
# Ukraine                 84.071429   9.214286
# Bosnia and Herzegovina  86.500000  12.500000
# India                   90.222222  13.333333
# Armenia                 87.500000  14.500000
# Bulgaria                87.936170  14.645390
# Romania                 86.400000  15.241667
# Macedonia               86.833333  15.583333
# Slovakia                87.000000  16.000000
# Cyprus                  87.181818  16.272727
# Moldova                 87.203390  16.745763
# China                   89.000000  18.000000
# Peru                    83.562500  18.062500
# Georgia                 87.686047  19.321429
# Morocco                 88.571429  19.500000
# Chile                   86.493515  20.786458
# Greece                  87.283262  22.364425
# Luxembourg              88.666667  23.333333
# Brazil                  84.673077  23.765957
# Czech Republic          87.250000  24.250000
# Serbia                  87.500000  24.500000
# Argentina               86.710263  24.510117
# Turkey                  88.088889  24.633333
# South Africa            88.056388  24.668987
# Slovenia                88.068966  24.812500
# Croatia                 87.219178  25.450704
# Portugal                88.250220  26.218256
# Uruguay                 86.752294  26.403670
# Mexico                  85.257143  26.785714
# New Zealand             88.303030  26.931785
# Spain                   87.288337  28.215275
# Lebanon                 87.685714  30.685714
# Austria                 90.101345  30.762772
# Israel                  88.471287  31.768916
# Australia               88.580507  35.437663
# Canada                  89.369650  35.712598
# US                      88.563720  36.573464
# Italy                   88.562231  39.663770
# Hungary                 89.191781  40.648276
# France                  88.845109  41.139120
# Germany                 89.851732  42.257547
# England                 91.581081  51.681159
# Switzerland             88.571429  85.285714
# Egypt                   84.000000        NaN

# %%
wine_group_country.variety.count()
# Out:
# country
# Argentina                  3800
# Armenia                       2
# Australia                  2329
# Austria                    3345
# Bosnia and Herzegovina        2
# Brazil                       52
# Bulgaria                    141
# Canada                      257
# Chile                      4471
# China                         1
# Croatia                      73
# Cyprus                       11
# Czech Republic               12
# Egypt                         1
# England                      74
# France                    22093
# Georgia                      86
# Germany                    2165
# Greece                      466
# Hungary                     146
# India                         9
# Israel                      505
# Italy                     19540
# Lebanon                      35
# Luxembourg                    6
# Macedonia                    12
# Mexico                       70
# Moldova                      59
# Morocco                      28
# New Zealand                1419
# Peru                         16
# Portugal                   5691
# Romania                     120
# Serbia                       12
# Slovakia                      1
# Slovenia                     87
# South Africa               1401
# Spain                      6645
# Switzerland                   7
# Turkey                       90
# US                        54504
# Ukraine                      14
# Uruguay                     109
# Name: variety, dtype: int64

# %%
wine_df_reordered.groupby("points").price.min()
# Out:
# points
# 80      5.0
# 81      5.0
# 82      4.0
# 83      4.0
# 84      4.0
# 85      4.0
# 86      4.0
# 87      5.0
# 88      6.0
# 89      7.0
# 90      8.0
# 91      7.0
# 92     11.0
# 93     12.0
# 94     13.0
# 95     20.0
# 96     20.0
# 97     35.0
# 98     50.0
# 99     44.0
# 100    80.0
# Name: price, dtype: float64

# %%
import numpy as np

wine_df_reordered.groupby("points").price.agg([np.min, np.max])
# Out:
#         amin    amax
# points
# 80       5.0    69.0
# 81       5.0   130.0
# 82       4.0   150.0
# 83       4.0   225.0
# 84       4.0   225.0
# 85       4.0   320.0
# 86       4.0   170.0
# 87       5.0   800.0
# 88       6.0  3300.0
# 89       7.0   500.0
# 90       8.0   510.0
# 91       7.0  2013.0
# 92      11.0   750.0
# 93      12.0   770.0
# 94      13.0  1125.0
# 95      20.0   973.0
# 96      20.0  2500.0
# 97      35.0  2000.0
# 98      50.0  1900.0
# 99      44.0   850.0
# 100     80.0  1500.0

# %% [markdown]
# # Small Check:
#
# Q 04.1: Fill-in "XXX" so that evaluate each groups' max price minus mean price. What type result will have?
#
#
# ---

# %% [markdown]
# We can use even custom functions to use for aggregation

# %%
def max_minus_mean(grouped_data):
    return(XXX)

wine_df_reordered.groupby("country").XXX.agg(max_minus_mean)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-23e3beadf69a> in <module>()
#       2     return(XXX)
#       3
# ----> 4 wine_df_reordered.groupby("country").XXX.agg(max_minus_mean)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     702
#     703         raise AttributeError(
# --> 704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#     706
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'XXX'

# %%
def max_minus_mean(grouped_data):
    return(grouped_data.max() - grouped_data.mean())

wine_df_reordered.groupby("country").price.agg(max_minus_mean)
# Out:
# country
# Argentina                  205.489883
# Armenia                      0.500000
# Australia                  814.562337
# Austria                   1069.237228
# Bosnia and Herzegovina       0.500000
# Brazil                      36.234043
# Bulgaria                    85.354610
# Canada                      84.287402
# Chile                      379.213542
# China                        0.000000
# Croatia                     39.549296
# Cyprus                       4.727273
# Czech Republic              20.750000
# Egypt                             NaN
# England                     43.318841
# France                    3258.860880
# Georgia                     20.678571
# Germany                    732.742453
# Greece                      56.635575
# Hungary                    723.351724
# India                        6.666667
# Israel                     118.231084
# Italy                      860.336230
# Lebanon                     44.314286
# Luxembourg                   6.666667
# Macedonia                    4.416667
# Mexico                      81.214286
# Moldova                     25.254237
# Morocco                     20.500000
# New Zealand                103.068215
# Peru                        49.937500
# Portugal                   973.781744
# Romania                    304.758333
# Serbia                      17.500000
# Slovakia                     0.000000
# Slovenia                    65.187500
# South Africa               305.331013
# Spain                      741.784725
# Switzerland                 74.714286
# Turkey                      95.366667
# US                        1976.426536
# Ukraine                      3.785714
# Uruguay                    103.596330
# Name: price, dtype: float64

# %%
#Convert back to DataFrame
wine_df_reordered.groupby("country").price.agg(max_minus_mean).reset_index()
# Out:
#                    country        price
# 0                Argentina   205.489883
# 1                  Armenia     0.500000
# 2                Australia   814.562337
# 3                  Austria  1069.237228
# 4   Bosnia and Herzegovina     0.500000
# 5                   Brazil    36.234043
# 6                 Bulgaria    85.354610
# 7                   Canada    84.287402
# 8                    Chile   379.213542
# 9                    China     0.000000
# 10                 Croatia    39.549296
# 11                  Cyprus     4.727273
# 12          Czech Republic    20.750000
# 13                   Egypt          NaN
# 14                 England    43.318841
# 15                  France  3258.860880
# 16                 Georgia    20.678571
# 17                 Germany   732.742453
# 18                  Greece    56.635575
# 19                 Hungary   723.351724
# 20                   India     6.666667
# 21                  Israel   118.231084
# 22                   Italy   860.336230
# 23                 Lebanon    44.314286
# 24              Luxembourg     6.666667
# 25               Macedonia     4.416667
# 26                  Mexico    81.214286
# 27                 Moldova    25.254237
# 28                 Morocco    20.500000
# 29             New Zealand   103.068215
# 30                    Peru    49.937500
# 31                Portugal   973.781744
# 32                 Romania   304.758333
# 33                  Serbia    17.500000
# 34                Slovakia     0.000000
# 35                Slovenia    65.187500
# 36            South Africa   305.331013
# 37                   Spain   741.784725
# 38             Switzerland    74.714286
# 39                  Turkey    95.366667
# 40                      US  1976.426536
# 41                 Ukraine     3.785714
# 42                 Uruguay   103.596330

# %% [markdown]
# # Mapping
#
# Map and apply functions
#
# **Map** takes one set of values and "maps" them to another set of values. Map expects Series as a data type and returns Series as well. Map is used for:
#
# 1.   Create new representations from existing data
# 2.   Transformation of data from the one format to another

# %%
wine_df_reordered.head()
# Out:
#     country  ...                                              title
# 0     Italy  ...                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1  Portugal  ...      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        US  ...      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3        US  ...  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        US  ...  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
# [5 rows x 12 columns]

# %%
# %%timeit
wine_points_max = wine_df_reordered.points.max()
wine_df_reordered.points.map(lambda x: x-wine_points_max)
# Out:
# 0        -13
# 1        -13
# 2        -13
# 3        -13
# 4        -13
#           ..
# 129966   -10
# 129967   -10
# 129968   -10
# 129969   -10
# 129970   -10
# Name: points, Length: 129971, dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **map** function has been called, but original DataFrame wasn't changed. To change it we shall assign resulted Series to a column.

# %%
wine_df_reordered.loc["points"] = wine_df_reordered.points.map(lambda x: x-wine_points_max) #izmaina series
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
wine_df_reordered.head()
# Out:
#     country  ...                                              title
# 0     Italy  ...                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1  Portugal  ...      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        US  ...      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3        US  ...  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        US  ...  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
# [5 rows x 12 columns]

# %% [markdown]
# But...it wasn't changed either. Ok, there is a worning - we shall assign to a specific notation of indexing, thus modification of *orginal* happens not *copy* of the DataFrame.

# %%
wine_df_reordered.loc[:,"points"] = wine_df_reordered.points.map(lambda x: x-wine_points_max)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
wine_df_reordered.head()
# Out:
#     country  ...                                              title
# 0     Italy  ...                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1  Portugal  ...      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        US  ...      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3        US  ...  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        US  ...  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
# [5 rows x 12 columns]

# %% [markdown]
# **apply** function is second option how to apply change **to whole DataFrame** row by row

# %%
wine_df_reordered_price_mean = wine_df_reordered["price"].mean() #apply izmanto visu dataframe

def mean_price(row):
  row.price = row.price - wine_df_reordered_price_mean
  return row

wine_df_reordered.apply(mean_price, axis="columns")
# Out:
#          country  ...                                              title
# 0          Italy  ...                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1       Portugal  ...      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2             US  ...      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3             US  ...  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4             US  ...  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# ...          ...  ...                                                ...
# 129967        US  ...                  Citation 2004 Pinot Noir (Oregon)
# 129968    France  ...  Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 129969    France  ...      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970    France  ...  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
# points       NaN  ...                                                NaN
#
# [129972 rows x 12 columns]

# %% [markdown]
# The same as with **map** function - *orginal* wasn't changed.

# %% [markdown]
# **Q04.1** Translate to 5-start rating
#
# Transalte rating (*points*) in the DataFrame to star-rating as per rule:
#
# 3 stars: 95 or higher;
# 2 stars: a rating of at least 85 but less than 95
# 1 star: any other left rating.

# %%
wine_df_reordered_2 = wine_df_reordered

def stars(row):
  if row.points >= 95:
    row.points = "***"
  elif row.points >= 85 and < 95:
    row.points = "**"
  else:
    row.points = "*"
  return row

wine_df_reordered_2.loc[:,"points"] = wine_df_reordered_2.points.map(stars)
# Out:
#   File "<ipython-input-32-251164cae540>", line 6
#     elif row.points >= 85 and < 95:
#                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Map and Apply with Aggregations

# %%
wine_df.groupby("winery").apply(lambda df: df.title.iloc[0]) #izvelk 0 elementu
# Out:
# winery
# 1+1=3                                     1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                            10 Knots 2010 Viognier (Paso Robles)
# 100 Percent Wine              100 Percent Wine 2015 Moscato (California)
# 1000 Stories           1000 Stories 2013 Bourbon Barrel Aged Zinfande...
# 1070 Green                  1070 Green 2011 Sauvignon Blanc (Rutherford)
#                                              ...
# Órale                       Órale 2011 Cabronita Red (Santa Ynez Valley)
# Öko                    Öko 2013 Made With Organically Grown Grapes Ma...
# Ökonomierat Rebholz    Ökonomierat Rebholz 2007 Von Rotliegenden Spät...
# àMaurice               àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                                    Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
wine_df.groupby("winery").apply(lambda df: df.title)
# Out:
# winery
# 1+1=3     20319                        1+1=3 NV Rosé Sparkling (Cava)
#           33657     1+1=3 NV Cygnus Brut Nature Reserva Made With ...
#           55163                        1+1=3 NV Brut Sparkling (Cava)
#           56109     1+1=3 NV Cygnus Brut Nature Reserva Made With ...
#           63807          1+1=3 2008 Rosé Cabernet Sauvignon (Penedès)
#                                           ...
# àMaurice  124544           àMaurice 2009 Syrah (Columbia Valley (WA))
#           128023       àMaurice NV Pour Me Red (Columbia Valley (WA))
# Štoka     10290                       Štoka 2009 Izbrani Teran (Kras)
#           70504                    Štoka 2011 Grganja Vitovska (Kras)
#           70505                       Štoka 2011 Izbrani Teran (Kras)
# Name: title, Length: 129971, dtype: object

# %% [markdown]
# # Multi-Indexing

# %%
mean_points_by_country_province = wine_df.groupby(["country", "province"]).points.agg(["mean"])
mean_points_by_country_province
# Out:
#                                  mean
# country   province
# Argentina Mendoza Province  86.826593
#           Other             86.001866
# Armenia   Armenia           87.500000
# Australia Australia Other   85.518367
#           New South Wales   87.694118
# ...                               ...
# Uruguay   Juanico           86.333333
#           Montevideo        88.272727
#           Progreso          86.818182
#           San Jose          84.000000
#           Uruguay           86.833333
#
# [425 rows x 1 columns]

# %%
type(mean_points_by_country_province.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %% [markdown]
# To easy data processing you can flatten multi-indexed DataFrame and make regular 2D array.

# %%
mean_points_by_country_province.reset_index()
# Out:
#        country          province       mean
# 0    Argentina  Mendoza Province  86.826593
# 1    Argentina             Other  86.001866
# 2      Armenia           Armenia  87.500000
# 3    Australia   Australia Other  85.518367
# 4    Australia   New South Wales  87.694118
# ..         ...               ...        ...
# 420    Uruguay           Juanico  86.333333
# 421    Uruguay        Montevideo  88.272727
# 422    Uruguay          Progreso  86.818182
# 423    Uruguay          San Jose  84.000000
# 424    Uruguay           Uruguay  86.833333
#
# [425 rows x 3 columns]

# %%
mean_points_by_country_province.loc[["France"]]
# Out:
#                                    mean
# country province
# France  Alsace                89.372131
#         Beaujolais            87.954981
#         Bordeaux              88.658980
#         Burgundy              89.569347
#         Champagne             90.234966
#         France Other          86.465976
#         Languedoc-Roussillon  87.086460
#         Loire Valley          88.493534
#         Provence              88.210253
#         Rhône Valley          89.007401
#         Southwest France      88.607452

# %%
mean_points_by_country_province.loc[["France"]].sort_values(by="mean", ascending=False)
# Out:
#                                    mean
# country province
# France  Champagne             90.234966
#         Burgundy              89.569347
#         Alsace                89.372131
#         Rhône Valley          89.007401
#         Bordeaux              88.658980
#         Southwest France      88.607452
#         Loire Valley          88.493534
#         Provence              88.210253
#         Beaujolais            87.954981
#         Languedoc-Roussillon  87.086460
#         France Other          86.465976

# %% [markdown]
# **Q 04.2** Best price/quality
#
# Return a pair: *{"_Country_": "_Variety_"}* and tell with pair combinations are most common in the Data Set?
#
# Hint: Use Multi-Index dataframe and sort by size.

# %%
country_variety_wines = wine_df.groupby(["country", "variety"]).size().sort_values(ascending=False)
country_variety_wines
# Out:
# country    variety
# US         Pinot Noir                  9885
#            Cabernet Sauvignon          7315
#            Chardonnay                  6801
# France     Bordeaux-style Red Blend    4725
# Italy      Red Blend                   3624
#                                        ...
# Uruguay    Tempranillo-Tannat             1
# Italy      Pignolo                        1
#            Muscat                         1
#            Moscato di Noto                1
# Argentina  Barbera                        1
# Length: 1612, dtype: int64

# %% [markdown]
# **Q 04.2** Best price/quality
#
# Which wine has best price/quality relation?
#
# Suggestion: use *idxmax()* pandas function.

# %%
# wine_df_price_perf = wine_df
wine_df_price_perf = wine_df.points / wine_df.price
# wine_df_price_perf.sort_values(['Result'] , ascending=False)

# otrs pareizais vairants

price_quality_id = wine_df_price_perf.idxmax()
best_wine_quality = wine_df.loc[price_quality_id, "title"] + str(wine_df.loc[price_quality_id, "price"]) # vajag pateikt, ka pieliek klāt stringu str funkciju
best_wine_quality
 #zemākā kvalitāte ar min
# Out:
# 'Bandit NV Merlot (California)4.0'

# %%
price_quality_id = wine_df_price_perf.idxmin()
worst_wine_quality = wine_df.loc[price_quality_id, "title"] + str(wine_df.loc[price_quality_id, "price"]) # vajag pateikt, ka pieliek klāt stringu str funkciju
worst_wine_quality
# Out:
# 'Château les Ormes Sorbet 2013  Médoc3300.0'

# %% [markdown]
# # Data Types
#
# With specific functions you can identify and convert data types of DataFrame

# %% [markdown]
# ![https://pbpython.com/pandas_dtypes.html](data:image/png;base64,...)

# %% [markdown]
# *Category* - categorical data:
# 1.   Size (X-Small, Small, Medium, Large, X-Large)
# 2.   Color (Red, Black, White)
# 3.   Style (Short sleeve, long sleeve)
# 4.   Material (Cotton, Polyester)
#
# Pros:
#
#
# 1.   Summarization and reporting is done better (it can compare e.g. Small < Large)
# 2.   Performance increased: RAM usage, group-by increase
# 3.   Visualization and some analytical (e.g. ML) libraries designed to work with categorical data even better.
#
# Cons:
#
# 1.  Background conversion of data (e.g. concatenating of two DataFrames) - *category* data-type can be lost.
# 2.  In case you convert to category data type, but not listed all categories - such value will be converted to NaN.

# %%
wine_df_retype = wine_df
wine_df_retype.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                129908 non-null  object
#  1   description            129971 non-null  object
#  2   designation            92506 non-null   object
#  3   points                 129971 non-null  int64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  object
#  6   region_1               108724 non-null  object
#  7   region_2               50511 non-null   object
#  8   taster_name            103727 non-null  object
#  9   taster_twitter_handle  98758 non-null   object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 18.9+ MB

# %%
wine_df_retype.points = wine_df_retype.points.astype("float64")
wine_df_retype.info() #maina tipu pointiem
wine_df_retype.points = wine_df_retype.points.astype("int64")
wine_df_retype.info() #maina tipu pointiem
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                129908 non-null  object
#  1   description            129971 non-null  object
#  2   designation            92506 non-null   object
#  3   points                 129971 non-null  float64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  object
#  6   region_1               108724 non-null  object
#  7   region_2               50511 non-null   object
#  8   taster_name            103727 non-null  object
#  9   taster_twitter_handle  98758 non-null   object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 18.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                129908 non-null  object
#  1   description            129971 non-null  object
#  2   designation            92506 non-null   object
#  3   points                 129971 non-null  int64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  object
#  6   region_1               108724 non-null  object
#  7   region_2               50511 non-null   object
#  8   taster_name            103727 non-null  object
#  9   taster_twitter_handle  98758 non-null   object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 18.9+ MB
