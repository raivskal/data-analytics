# %% [markdown]
# # I. Introduction
#
# Data is coming from: https://archive.ics.uci.edu/ml/index.php

# %% [markdown]
# #1. Import Libraries

# %%
import tensorflow as tf

tf.__version__

# %% [markdown]
# #2. Pre-processing

# %% [markdown]
# **Pre-processing of Trainig set**
#
#
# A trick to overcome overfitting.

# %% [markdown]
# **Pre-processing of Test set**

# %% [markdown]
# #3. Creation of CNN
#
# ![image.png](data:image/png;base64,...)
#
#
# *3.1) CNN Initialization*

# %% [markdown]
# *3.2) Create Convolution layer*

# %% [markdown]
# *3.4) Pooling*

# %% [markdown]
# *3.5) Create Next Convolutional layer*

# %% [markdown]
# *3.5) Flatten*

# %% [markdown]
# *3.5) Dense of Full-Connection*

# %% [markdown]
# *3.5) Output Layer*

# %% [markdown]
# # 4. Training of CNN Model

# %% [markdown]
# **a) Compile CNN**

# %% [markdown]
# **a) Train CNN**

# %% [markdown]
# **5. Validate CNN Result**
